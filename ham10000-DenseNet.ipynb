# %%
import os
import torch
from torch import nn

torch.__version__
# Out:
# '2.0.0'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import os
import zipfile

from pathlib import Path
import random
import shutil
from shutil import copyfile

import requests
import pandas as pd

# Setup path to data folder
data_path = Path("/kaggle/input/ham10000-splitted/Images splitted/Splitted")
image_path = data_path # FOLDER path = splitted dataset into Train & Test

# %%
## tasks -
##          1. taking the "train" folder images into "____all" folder using train.csv with making no of folder-classes inside it

# import shutil

# csv_location = data_path / "train.csv"
# # csv_location_test = data_path / "test.csv"

# df_train_csv = pd.read_csv(csv_location)
# # df_test_csv = pd.read_csv(csv_location_test)

# class_names = df_train_csv['diagnosis'].unique()


# COMMENT IT IF MAKING DIRECTORIES && NOT COPYING----------(train)-------------------

# ## making directories according to no of classes
# for i in range(len(class_names)):
#     name = class_names[i]
#     os.makedirs(f'{image_path_all}/{name}', exist_ok=True)  




# ## taking images from train folder --> __all forder's class folder
# for i in range(len(df_train_csv)):
#     image_name = df_train_csv["id_code"][i]
#     class_name = df_train_csv["diagnosis"][i]
#     source_path = data_path / "train_images" / f"{image_name}.png"
#     destination = image_path_all/ f"{class_name}"/ f"{image_name}.png"
#     shutil.copyfile(source_path, destination)

# COMMENT IT IF NOT COPYING--------------------------------(train)-------------------

# %%
# no of samples per class

# classes = os.listdir(image_path_all)
# classes_no_of_data_dict = {}

# for i in range(len(classes)):
#     classes_no_of_data_dict[classes[i]] = len(os.listdir(image_path_all/classes[i]))

# classes_no_of_data_dict






## When you only uploda splitted folder
classes = os.listdir(f'{image_path}/train')
classes_no_of_data_dict = {}
# classes.remove("desktop.ini")
classes

for i in range(len(classes)):
    classes_no_of_data_dict[classes[i]] = len(os.listdir(f'{image_path}/train/{classes[i]}'))
    
# for i in range(len(classes)):
#     temp = len(os.listdir(f'{image_path}/test/{classes[i]}'))
#     classes_no_of_data_dict[classes[i]] = classes_no_of_data_dict[classes[i]] + temp

classes_no_of_data_dict
# Out:
# {'mel': 891,
#  'vasc': 114,
#  'df': 93,
#  'nv': 5365,
#  'bkl': 880,
#  'akiec': 262,
#  'bcc': 412}

# %% [markdown]
# ### Augmentation(WIP)

# %%
# classlist = os.listdir(image_path_all)    
# filepaths = []
# labels = []


# for klass in classlist:
#     classpath=os.path.join(image_path_all,klass)
#     if os.path.isdir(classpath):
#         flist=os.listdir(classpath)        
#         for f in flist:
#             fpath=os.path.join(classpath,f)        
#             filepaths.append(fpath)
#             labels.append(klass)
            
# Fseries=pd.Series(filepaths, name='filepaths')
# Lseries=pd.Series(labels, name='labels')    
# df=pd.concat([Fseries, Lseries], axis=1)  


# print (df.head())
# print('df length: ', len(df))
# print (df['labels'].value_counts())

# %%
# import shutil
# from shutil import copyfile

# working_dir = data_path

# aug_dir=os.path.join(working_dir, 'aug')

# if os.path.isdir(aug_dir):
#     shutil.rmtree(aug_dir)
# os.mkdir(aug_dir)

# for label in df['labels'].unique():
#     dir_path=os.path.join(aug_dir,label)    
#     os.mkdir(dir_path)
    
# print(os.listdir(aug_dir))

# %%
# Setup train and testing paths
train_dir = image_path / "train"
test_dir = image_path / "test"

train_dir, test_dir
# Out:
# (PosixPath('/kaggle/input/ham10000-splitted/Images splitted/Splitted/train'),
#  PosixPath('/kaggle/input/ham10000-splitted/Images splitted/Splitted/test'))

# %% [markdown]
# ## 2. Create Datasets and DataLoaders

# %% [markdown]
# ### 2.1 Manual Transform

# %%
from torchvision import datasets, transforms
from torchvision.transforms.functional import InterpolationMode

# Create image size (from Table 3 in the ViT paper) 
IMG_SIZE = 224
# IMG_SIZE = 64
# IMG_SIZE = 56
# IMG_SIZE = 150
# IMG_SIZE = 450
# IMG_SIZE = 600

# Create transform pipeline manually   
data_transform = transforms.Compose([
#     transforms.CenterCrop(200),
#     transforms.RandAugment(num_ops = 8, 
#                            magnitude = 9, 
#                            num_magnitude_bins = 31, 
#                            interpolation = InterpolationMode.BILINEAR, 
#                            ),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
#     transforms.RandomRotation((-120,120)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
#     transforms.RandomAffine(degrees=360, scale=(1.0, 1.3)),
#     transforms.RandomAdjustSharpness(sharpness_factor=0),
#     transforms.RandomAdjustSharpness(sharpness_factor=2),
    transforms.RandomPerspective(distortion_scale=0.2),
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    
    # Calculated for train data
    transforms.Normalize([0.5018, 0.5015, 0.5013], [0.1029, 0.0985, 0.0807]),
])     

print(f"Manually created transforms: {data_transform}")





data_transform_test = transforms.Compose([
#     transforms.CenterCrop(200),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
   
    # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),

    # Calculated for test data
    transforms.Normalize([0.5018, 0.5015, 0.5013], [0.1029, 0.0985, 0.0807]),
])  


# Use ImageFolder to create dataset(s)
train_data = datasets.ImageFolder(root=train_dir, # target folder of images
                                  transform=data_transform, # transforms to perform on data (images)
                                  target_transform=None) # transforms to perform on labels (if necessary)


test_data = datasets.ImageFolder(root=test_dir,
                                 transform=data_transform_test,
                                )

print(f"Train data:\n{train_data}\nTest data:\n{test_data}")
# Out:
# Manually created transforms: Compose(
#     Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#     ToTensor()
#     RandomHorizontalFlip(p=0.5)
#     RandomVerticalFlip(p=0.5)
#     RandomPerspective(p=0.5)
#     Normalize(mean=[0.5018, 0.5015, 0.5013], std=[0.1029, 0.0985, 0.0807])
# )
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 8017
#     Root location: /kaggle/input/ham10000-splitted/Images splitted/Splitted/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                RandomPerspective(p=0.5)
#                Normalize(mean=[0.5018, 0.5015, 0.5013], std=[0.1029, 0.0985, 0.0807])
#            )
# Test data:
# Dataset ImageFolder
#     Number of datapoints: 1998
#     Root location: /kaggle/input/ham10000-splitted/Images splitted/Splitted/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#                Normalize(mean=[0.5018, 0.5015, 0.5013], std=[0.1029, 0.0985, 0.0807])
#            )

# %% [markdown]
# ### 2.2 Auto Transform

# %%
import torchvision

# Get a set of pretrained model weights
weights = torchvision.models.DenseNet121_Weights.DEFAULT # .DEFAULT = best available weights from pretraining on ImageNet
weights
# Out:
# DenseNet121_Weights.IMAGENET1K_V1

# %%
# Get the transforms used to create our pretrained weights
auto_transforms = weights.transforms()
auto_transforms
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %%
# from torchvision import datasets, transforms

# # Use ImageFolder to create dataset(s)
# train_data = datasets.ImageFolder(root=train_dir, # target folder of images
#                                   transform=auto_transforms, # transforms to perform on data (images)
#                                   target_transform=None) # transforms to perform on labels (if necessary)

# test_data = datasets.ImageFolder(root=test_dir, 
#                                  transform=auto_transforms)

# print(f"Train data:\n{train_data}\nTest data:\n{test_data}")

# %%
# Get class names as a list
class_names = train_data.classes
class_names
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
# Can also get class names as a dict
class_dict = train_data.class_to_idx
class_dict
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %%
# weights = []

# for (X,y) in train_data:
#     if y == 0:
#         weights.append(1.0/1445) # Aptos
# #         weights.append(1.0/53728)

#     if y == 1:
#         weights.append(1.0/297)
# #         weights.append(1.0/5261)
#     if y == 2:
#         weights.append(1.0/800)
# #         weights.append(1.0/11322)
#     if y == 3:
#         weights.append(1.0/237)
# #         weights.append(1.0/1768)
#     if y == 4:
#         weights.append(1.0/155)
# #         weights.append(1.0/1825)

# %%
# Check the lengths
len(train_data), len(test_data)
# Out:
# (8017, 1998)

# %%
# ## testing optimal num_worker value

# from time import time
# import multiprocessing as mp
# from torch.utils.data import DataLoader

# for num_workers in range(1, 100, 1):  
#     train_loader = DataLoader(test_data,shuffle=True,num_workers=num_workers,batch_size=1,pin_memory=True)
#     start = time()
#     for epoch in range(1):
#         for i, data in enumerate(train_loader, 0):
#             pass
#     end = time()
#     print("Finish with:{} second, num_workers={}".format(end - start, num_workers))

# %%
# Turn train and test Datasets into DataLoaders
from torch.utils.data import DataLoader, WeightedRandomSampler
# from torchsampler import ImbalancedDatasetSampler

BATCH_SIZE = 32

# sampler = WeightedRandomSampler(sweights, 
#                                 num_samples=8017,
#                                 replacement=True)



train_dataloader = DataLoader(dataset=train_data, 
                              batch_size=BATCH_SIZE, # how many samples per batch?
                              num_workers=4, # how many subprocesses to use for data loading? (higher = more)
                              shuffle=True,
                              pin_memory=True,
#                               sampler=sampler, 
                              ) # shuffle the data?



test_dataloader = DataLoader(dataset=test_data, 
                             batch_size=BATCH_SIZE, 
                             num_workers=4, 
                             shuffle=False,
                             pin_memory=True,
                             ) # don't usually need to shuffle testing data


len(train_dataloader), len(test_dataloader)
# Out:
# (251, 63)

# %%
# # python code to calculate mean and std 

# import torch
# from torch.utils.data import DataLoader

# batch_size = 64


# def batch_mean_and_sd(test_dataloader):
    
#     cnt = 0
#     fst_moment = torch.empty(3)
#     snd_moment = torch.empty(3)

#     for images, _ in test_dataloader:
#         b, c, h, w = images.shape
#         nb_pixels = b * h * w
#         sum_ = torch.sum(images, dim=[0, 2, 3])
#         sum_of_square = torch.sum(images ** 2,
#                                   dim=[0, 2, 3])
#         fst_moment = (cnt * fst_moment + sum_) / (
#                       cnt + nb_pixels)
#         snd_moment = (cnt * snd_moment + sum_of_square) / (
#                             cnt + nb_pixels)
#         cnt += nb_pixels

#     mean, std = fst_moment, torch.sqrt(
#       snd_moment - fst_moment ** 2)        
#     return mean,std
  
    
    
# mean, std = batch_mean_and_sd(train_dataloader)
# print("mean and std: \n", mean, std)

# %%
# Check out single image size/shape
img, label = next(iter(train_dataloader))

# Batch size will now be 1, try changing the batch_size parameter above and see what happens
print(f"Image shape: {img.shape} -> [batch_size, color_channels, height, width]")
print(f"Label shape: {label.shape}")
# Out:
# Image shape: torch.Size([32, 3, 224, 224]) -> [batch_size, color_channels, height, width]
# Label shape: torch.Size([32])

# %% [markdown]
# ### Experimentations

# %%
# ## Monitoring labels in batches
# total = [0,0,0,0,0]
# for batch, (X, y) in enumerate(train_dataloader):
#     print(f"{batch}th batch")
#     Y = y.tolist()
#     print(f"0 : {Y.count(0)}\n1 : {Y.count(1)}\n2 : {Y.count(2)}\n3 : {Y.count(3)}\n4 : {Y.count(4)}")
#     total[0] += Y.count(0)
#     total[1] += Y.count(1)
#     total[2] += Y.count(2)
#     total[3] += Y.count(3)
#     total[4] += Y.count(4)
# total

# %%
# a = torch.randn(4, 4)
# a
# # tensor([[ 1.3398,  0.2663, -0.2686,  0.2450],
# #         [-0.7401, -0.8805, -0.3402, -1.1936],
# #         [ 0.4907, -1.3948, -1.0691, -0.3132],
# #         [-1.6092,  0.5419, -0.2993,  0.3195]])
# # >>> torch.argmax(a)
# # tensor(0)

# %%
# torch.argmax(a, dim=1)

# %%
# y_predicted = []
# Y = []
# for batch, (X, y) in enumerate(train_dataloader):
#     # print(y, end="\n\n")
#     X = X.to(device)
#     y_pred = model(X)
#     y_predicted = y_pred
#     Y = y 
#     # print(y_pred)
#     break
# print(y_predicted,end="/n")
# print(Y)

# %%
# logits = torch.softmax(y_predicted, dim=1)
# logits

# %%
# logits + logits

# %%
# y_pred_class = torch.argmax(torch.softmax(y_predicted, dim=1), dim=1)
# print(y_pred_class)

# Y = Y.to(device)
# y_pred_class = y_pred_class.to(device)

# %%
# (y_pred_class == Y).sum().item()/len(y_pred_class)

# %%
# Get a batch of images
image_batch, label_batch = next(iter(train_dataloader))

# Get a single image from the batch
image, label = image_batch[0], label_batch[0]

# View the batch shapes
image.shape, label
# Out:
# (torch.Size([3, 224, 224]), tensor(5))

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Sequential as Seq
# from gcn_lib import Grapher, act_layer

import sys
sys.path.append("/kaggle/input/vig-pytorch/")
from gcn_lib import Grapher, act_layer


from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
from timm.models.helpers import load_pretrained
from timm.models.layers import DropPath, to_2tuple, trunc_normal_
from timm.models.registry import register_model

# %%
model = torchvision.models.densenet121(weights=weights).to(device)
# model
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 161MB/s]

# %%
from torchinfo import summary

model_summary = model

summary(model=model_summary,
        input_size=(16, 3, 224, 224), # (batch_size, num_patches, embedding_dimension)
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"])
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─Sequential (features)                       [16, 3, 224, 224]    [16, 1024, 7, 7]     --                   True
# │    └─Conv2d (conv0)                         [16, 3, 224, 224]    [16, 64, 112, 112]   9,408                True
# │    └─BatchNorm2d (norm0)                    [16, 64, 112, 112]   [16, 64, 112, 112]   128                  True
# │    └─ReLU (relu0)                           [16, 64, 112, 112]   [16, 64, 112, 112]   --                   --
# │    └─MaxPool2d (pool0)                      [16, 64, 112, 112]   [16, 64, 56, 56]     --                   --
# │    └─_DenseBlock (denseblock1)              [16, 64, 56, 56]     [16, 256, 56, 56]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 64, 56, 56]     [16, 32, 56, 56]     45,440               True
# │    │    └─_DenseLayer (denselayer2)         [16, 64, 56, 56]     [16, 32, 56, 56]     49,600               True
# │    │    └─_DenseLayer (denselayer3)         [16, 64, 56, 56]     [16, 32, 56, 56]     53,760               True
# │    │    └─_DenseLayer (denselayer4)         [16, 64, 56, 56]     [16, 32, 56, 56]     57,920               True
# │    │    └─_DenseLayer (denselayer5)         [16, 64, 56, 56]     [16, 32, 56, 56]     62,080               True
# │    │    └─_DenseLayer (denselayer6)         [16, 64, 56, 56]     [16, 32, 56, 56]     66,240               True
# │    └─_Transition (transition1)              [16, 256, 56, 56]    [16, 128, 28, 28]    --                   True
# │    │    └─BatchNorm2d (norm)                [16, 256, 56, 56]    [16, 256, 56, 56]    512                  True
# │    │    └─ReLU (relu)                       [16, 256, 56, 56]    [16, 256, 56, 56]    --                   --
# │    │    └─Conv2d (conv)                     [16, 256, 56, 56]    [16, 128, 56, 56]    32,768               True
# │    │    └─AvgPool2d (pool)                  [16, 128, 56, 56]    [16, 128, 28, 28]    --                   --
# │    └─_DenseBlock (denseblock2)              [16, 128, 28, 28]    [16, 512, 28, 28]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 128, 28, 28]    [16, 32, 28, 28]     53,760               True
# │    │    └─_DenseLayer (denselayer2)         [16, 128, 28, 28]    [16, 32, 28, 28]     57,920               True
# │    │    └─_DenseLayer (denselayer3)         [16, 128, 28, 28]    [16, 32, 28, 28]     62,080               True
# │    │    └─_DenseLayer (denselayer4)         [16, 128, 28, 28]    [16, 32, 28, 28]     66,240               True
# │    │    └─_DenseLayer (denselayer5)         [16, 128, 28, 28]    [16, 32, 28, 28]     70,400               True
# │    │    └─_DenseLayer (denselayer6)         [16, 128, 28, 28]    [16, 32, 28, 28]     74,560               True
# │    │    └─_DenseLayer (denselayer7)         [16, 128, 28, 28]    [16, 32, 28, 28]     78,720               True
# │    │    └─_DenseLayer (denselayer8)         [16, 128, 28, 28]    [16, 32, 28, 28]     82,880               True
# │    │    └─_DenseLayer (denselayer9)         [16, 128, 28, 28]    [16, 32, 28, 28]     87,040               True
# │    │    └─_DenseLayer (denselayer10)        [16, 128, 28, 28]    [16, 32, 28, 28]     91,200               True
# │    │    └─_DenseLayer (denselayer11)        [16, 128, 28, 28]    [16, 32, 28, 28]     95,360               True
# │    │    └─_DenseLayer (denselayer12)        [16, 128, 28, 28]    [16, 32, 28, 28]     99,520               True
# │    └─_Transition (transition2)              [16, 512, 28, 28]    [16, 256, 14, 14]    --                   True
# │    │    └─BatchNorm2d (norm)                [16, 512, 28, 28]    [16, 512, 28, 28]    1,024                True
# │    │    └─ReLU (relu)                       [16, 512, 28, 28]    [16, 512, 28, 28]    --                   --
# │    │    └─Conv2d (conv)                     [16, 512, 28, 28]    [16, 256, 28, 28]    131,072              True
# │    │    └─AvgPool2d (pool)                  [16, 256, 28, 28]    [16, 256, 14, 14]    --                   --
# │    └─_DenseBlock (denseblock3)              [16, 256, 14, 14]    [16, 1024, 14, 14]   --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 256, 14, 14]    [16, 32, 14, 14]     70,400               True
# │    │    └─_DenseLayer (denselayer2)         [16, 256, 14, 14]    [16, 32, 14, 14]     74,560               True
# │    │    └─_DenseLayer (denselayer3)         [16, 256, 14, 14]    [16, 32, 14, 14]     78,720               True
# │    │    └─_DenseLayer (denselayer4)         [16, 256, 14, 14]    [16, 32, 14, 14]     82,880               True
# │    │    └─_DenseLayer (denselayer5)         [16, 256, 14, 14]    [16, 32, 14, 14]     87,040               True
# │    │    └─_DenseLayer (denselayer6)         [16, 256, 14, 14]    [16, 32, 14, 14]     91,200               True
# │    │    └─_DenseLayer (denselayer7)         [16, 256, 14, 14]    [16, 32, 14, 14]     95,360               True
# │    │    └─_DenseLayer (denselayer8)         [16, 256, 14, 14]    [16, 32, 14, 14]     99,520               True
# │    │    └─_DenseLayer (denselayer9)         [16, 256, 14, 14]    [16, 32, 14, 14]     103,680              True
# │    │    └─_DenseLayer (denselayer10)        [16, 256, 14, 14]    [16, 32, 14, 14]     107,840              True
# │    │    └─_DenseLayer (denselayer11)        [16, 256, 14, 14]    [16, 32, 14, 14]     112,000              True
# │    │    └─_DenseLayer (denselayer12)        [16, 256, 14, 14]    [16, 32, 14, 14]     116,160              True
# │    │    └─_DenseLayer (denselayer13)        [16, 256, 14, 14]    [16, 32, 14, 14]     120,320              True
# │    │    └─_DenseLayer (denselayer14)        [16, 256, 14, 14]    [16, 32, 14, 14]     124,480              True
# │    │    └─_DenseLayer (denselayer15)        [16, 256, 14, 14]    [16, 32, 14, 14]     128,640              True
# │    │    └─_DenseLayer (denselayer16)        [16, 256, 14, 14]    [16, 32, 14, 14]     132,800              True
# │    │    └─_DenseLayer (denselayer17)        [16, 256, 14, 14]    [16, 32, 14, 14]     136,960              True
# │    │    └─_DenseLayer (denselayer18)        [16, 256, 14, 14]    [16, 32, 14, 14]     141,120              True
# │    │    └─_DenseLayer (denselayer19)        [16, 256, 14, 14]    [16, 32, 14, 14]     145,280              True
# │    │    └─_DenseLayer (denselayer20)        [16, 256, 14, 14]    [16, 32, 14, 14]     149,440              True
# │    │    └─_DenseLayer (denselayer21)        [16, 256, 14, 14]    [16, 32, 14, 14]     153,600              True
# │    │    └─_DenseLayer (denselayer22)        [16, 256, 14, 14]    [16, 32, 14, 14]     157,760              True
# │    │    └─_DenseLayer (denselayer23)        [16, 256, 14, 14]    [16, 32, 14, 14]     161,920              True
# │    │    └─_DenseLayer (denselayer24)        [16, 256, 14, 14]    [16, 32, 14, 14]     166,080              True
# │    └─_Transition (transition3)              [16, 1024, 14, 14]   [16, 512, 7, 7]      --                   True
# │    │    └─BatchNorm2d (norm)                [16, 1024, 14, 14]   [16, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                       [16, 1024, 14, 14]   [16, 1024, 14, 14]   --                   --
# │    │    └─Conv2d (conv)                     [16, 1024, 14, 14]   [16, 512, 14, 14]    524,288              True
# │    │    └─AvgPool2d (pool)                  [16, 512, 14, 14]    [16, 512, 7, 7]      --                   --
# │    └─_DenseBlock (denseblock4)              [16, 512, 7, 7]      [16, 1024, 7, 7]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 512, 7, 7]      [16, 32, 7, 7]       103,680              True
# │    │    └─_DenseLayer (denselayer2)         [16, 512, 7, 7]      [16, 32, 7, 7]       107,840              True
# │    │    └─_DenseLayer (denselayer3)         [16, 512, 7, 7]      [16, 32, 7, 7]       112,000              True
# │    │    └─_DenseLayer (denselayer4)         [16, 512, 7, 7]      [16, 32, 7, 7]       116,160              True
# │    │    └─_DenseLayer (denselayer5)         [16, 512, 7, 7]      [16, 32, 7, 7]       120,320              True
# │    │    └─_DenseLayer (denselayer6)         [16, 512, 7, 7]      [16, 32, 7, 7]       124,480              True
# │    │    └─_DenseLayer (denselayer7)         [16, 512, 7, 7]      [16, 32, 7, 7]       128,640              True
# │    │    └─_DenseLayer (denselayer8)         [16, 512, 7, 7]      [16, 32, 7, 7]       132,800              True
# │    │    └─_DenseLayer (denselayer9)         [16, 512, 7, 7]      [16, 32, 7, 7]       136,960              True
# │    │    └─_DenseLayer (denselayer10)        [16, 512, 7, 7]      [16, 32, 7, 7]       141,120              True
# │    │    └─_DenseLayer (denselayer11)        [16, 512, 7, 7]      [16, 32, 7, 7]       145,280              True
# │    │    └─_DenseLayer (denselayer12)        [16, 512, 7, 7]      [16, 32, 7, 7]       149,440              True
# │    │    └─_DenseLayer (denselayer13)        [16, 512, 7, 7]      [16, 32, 7, 7]       153,600              True
# │    │    └─_DenseLayer (denselayer14)        [16, 512, 7, 7]      [16, 32, 7, 7]       157,760              True
# │    │    └─_DenseLayer (denselayer15)        [16, 512, 7, 7]      [16, 32, 7, 7]       161,920              True
# │    │    └─_DenseLayer (denselayer16)        [16, 512, 7, 7]      [16, 32, 7, 7]       166,080              True
# │    └─BatchNorm2d (norm5)                    [16, 1024, 7, 7]     [16, 1024, 7, 7]     2,048                True
# ├─Linear (classifier)                         [16, 1024]           [16, 1000]           1,025,000            True
# =============================================================================================================================
# Total params: 7,978,856
# Trainable params: 7,978,856
# Non-trainable params: 0
# Total mult-adds (G): 45.35
# =============================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 2888.66
# Params size (MB): 31.92
# Estimated Total Size (MB): 2930.21
# =============================================================================================================================

# %%
# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)


output_shape = len(class_names)


model.classifier = torch.nn.Linear(in_features=1024, 
                    out_features=output_shape, 
                    bias=True).to(device)

# %%
summary(model=model_summary,
        input_size=(16, 3, 224, 224), # (batch_size, num_patches, embedding_dimension)
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"])
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [16, 3, 224, 224]    [16, 7]              --                   True
# ├─Sequential (features)                       [16, 3, 224, 224]    [16, 1024, 7, 7]     --                   True
# │    └─Conv2d (conv0)                         [16, 3, 224, 224]    [16, 64, 112, 112]   9,408                True
# │    └─BatchNorm2d (norm0)                    [16, 64, 112, 112]   [16, 64, 112, 112]   128                  True
# │    └─ReLU (relu0)                           [16, 64, 112, 112]   [16, 64, 112, 112]   --                   --
# │    └─MaxPool2d (pool0)                      [16, 64, 112, 112]   [16, 64, 56, 56]     --                   --
# │    └─_DenseBlock (denseblock1)              [16, 64, 56, 56]     [16, 256, 56, 56]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 64, 56, 56]     [16, 32, 56, 56]     45,440               True
# │    │    └─_DenseLayer (denselayer2)         [16, 64, 56, 56]     [16, 32, 56, 56]     49,600               True
# │    │    └─_DenseLayer (denselayer3)         [16, 64, 56, 56]     [16, 32, 56, 56]     53,760               True
# │    │    └─_DenseLayer (denselayer4)         [16, 64, 56, 56]     [16, 32, 56, 56]     57,920               True
# │    │    └─_DenseLayer (denselayer5)         [16, 64, 56, 56]     [16, 32, 56, 56]     62,080               True
# │    │    └─_DenseLayer (denselayer6)         [16, 64, 56, 56]     [16, 32, 56, 56]     66,240               True
# │    └─_Transition (transition1)              [16, 256, 56, 56]    [16, 128, 28, 28]    --                   True
# │    │    └─BatchNorm2d (norm)                [16, 256, 56, 56]    [16, 256, 56, 56]    512                  True
# │    │    └─ReLU (relu)                       [16, 256, 56, 56]    [16, 256, 56, 56]    --                   --
# │    │    └─Conv2d (conv)                     [16, 256, 56, 56]    [16, 128, 56, 56]    32,768               True
# │    │    └─AvgPool2d (pool)                  [16, 128, 56, 56]    [16, 128, 28, 28]    --                   --
# │    └─_DenseBlock (denseblock2)              [16, 128, 28, 28]    [16, 512, 28, 28]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 128, 28, 28]    [16, 32, 28, 28]     53,760               True
# │    │    └─_DenseLayer (denselayer2)         [16, 128, 28, 28]    [16, 32, 28, 28]     57,920               True
# │    │    └─_DenseLayer (denselayer3)         [16, 128, 28, 28]    [16, 32, 28, 28]     62,080               True
# │    │    └─_DenseLayer (denselayer4)         [16, 128, 28, 28]    [16, 32, 28, 28]     66,240               True
# │    │    └─_DenseLayer (denselayer5)         [16, 128, 28, 28]    [16, 32, 28, 28]     70,400               True
# │    │    └─_DenseLayer (denselayer6)         [16, 128, 28, 28]    [16, 32, 28, 28]     74,560               True
# │    │    └─_DenseLayer (denselayer7)         [16, 128, 28, 28]    [16, 32, 28, 28]     78,720               True
# │    │    └─_DenseLayer (denselayer8)         [16, 128, 28, 28]    [16, 32, 28, 28]     82,880               True
# │    │    └─_DenseLayer (denselayer9)         [16, 128, 28, 28]    [16, 32, 28, 28]     87,040               True
# │    │    └─_DenseLayer (denselayer10)        [16, 128, 28, 28]    [16, 32, 28, 28]     91,200               True
# │    │    └─_DenseLayer (denselayer11)        [16, 128, 28, 28]    [16, 32, 28, 28]     95,360               True
# │    │    └─_DenseLayer (denselayer12)        [16, 128, 28, 28]    [16, 32, 28, 28]     99,520               True
# │    └─_Transition (transition2)              [16, 512, 28, 28]    [16, 256, 14, 14]    --                   True
# │    │    └─BatchNorm2d (norm)                [16, 512, 28, 28]    [16, 512, 28, 28]    1,024                True
# │    │    └─ReLU (relu)                       [16, 512, 28, 28]    [16, 512, 28, 28]    --                   --
# │    │    └─Conv2d (conv)                     [16, 512, 28, 28]    [16, 256, 28, 28]    131,072              True
# │    │    └─AvgPool2d (pool)                  [16, 256, 28, 28]    [16, 256, 14, 14]    --                   --
# │    └─_DenseBlock (denseblock3)              [16, 256, 14, 14]    [16, 1024, 14, 14]   --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 256, 14, 14]    [16, 32, 14, 14]     70,400               True
# │    │    └─_DenseLayer (denselayer2)         [16, 256, 14, 14]    [16, 32, 14, 14]     74,560               True
# │    │    └─_DenseLayer (denselayer3)         [16, 256, 14, 14]    [16, 32, 14, 14]     78,720               True
# │    │    └─_DenseLayer (denselayer4)         [16, 256, 14, 14]    [16, 32, 14, 14]     82,880               True
# │    │    └─_DenseLayer (denselayer5)         [16, 256, 14, 14]    [16, 32, 14, 14]     87,040               True
# │    │    └─_DenseLayer (denselayer6)         [16, 256, 14, 14]    [16, 32, 14, 14]     91,200               True
# │    │    └─_DenseLayer (denselayer7)         [16, 256, 14, 14]    [16, 32, 14, 14]     95,360               True
# │    │    └─_DenseLayer (denselayer8)         [16, 256, 14, 14]    [16, 32, 14, 14]     99,520               True
# │    │    └─_DenseLayer (denselayer9)         [16, 256, 14, 14]    [16, 32, 14, 14]     103,680              True
# │    │    └─_DenseLayer (denselayer10)        [16, 256, 14, 14]    [16, 32, 14, 14]     107,840              True
# │    │    └─_DenseLayer (denselayer11)        [16, 256, 14, 14]    [16, 32, 14, 14]     112,000              True
# │    │    └─_DenseLayer (denselayer12)        [16, 256, 14, 14]    [16, 32, 14, 14]     116,160              True
# │    │    └─_DenseLayer (denselayer13)        [16, 256, 14, 14]    [16, 32, 14, 14]     120,320              True
# │    │    └─_DenseLayer (denselayer14)        [16, 256, 14, 14]    [16, 32, 14, 14]     124,480              True
# │    │    └─_DenseLayer (denselayer15)        [16, 256, 14, 14]    [16, 32, 14, 14]     128,640              True
# │    │    └─_DenseLayer (denselayer16)        [16, 256, 14, 14]    [16, 32, 14, 14]     132,800              True
# │    │    └─_DenseLayer (denselayer17)        [16, 256, 14, 14]    [16, 32, 14, 14]     136,960              True
# │    │    └─_DenseLayer (denselayer18)        [16, 256, 14, 14]    [16, 32, 14, 14]     141,120              True
# │    │    └─_DenseLayer (denselayer19)        [16, 256, 14, 14]    [16, 32, 14, 14]     145,280              True
# │    │    └─_DenseLayer (denselayer20)        [16, 256, 14, 14]    [16, 32, 14, 14]     149,440              True
# │    │    └─_DenseLayer (denselayer21)        [16, 256, 14, 14]    [16, 32, 14, 14]     153,600              True
# │    │    └─_DenseLayer (denselayer22)        [16, 256, 14, 14]    [16, 32, 14, 14]     157,760              True
# │    │    └─_DenseLayer (denselayer23)        [16, 256, 14, 14]    [16, 32, 14, 14]     161,920              True
# │    │    └─_DenseLayer (denselayer24)        [16, 256, 14, 14]    [16, 32, 14, 14]     166,080              True
# │    └─_Transition (transition3)              [16, 1024, 14, 14]   [16, 512, 7, 7]      --                   True
# │    │    └─BatchNorm2d (norm)                [16, 1024, 14, 14]   [16, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                       [16, 1024, 14, 14]   [16, 1024, 14, 14]   --                   --
# │    │    └─Conv2d (conv)                     [16, 1024, 14, 14]   [16, 512, 14, 14]    524,288              True
# │    │    └─AvgPool2d (pool)                  [16, 512, 14, 14]    [16, 512, 7, 7]      --                   --
# │    └─_DenseBlock (denseblock4)              [16, 512, 7, 7]      [16, 1024, 7, 7]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 512, 7, 7]      [16, 32, 7, 7]       103,680              True
# │    │    └─_DenseLayer (denselayer2)         [16, 512, 7, 7]      [16, 32, 7, 7]       107,840              True
# │    │    └─_DenseLayer (denselayer3)         [16, 512, 7, 7]      [16, 32, 7, 7]       112,000              True
# │    │    └─_DenseLayer (denselayer4)         [16, 512, 7, 7]      [16, 32, 7, 7]       116,160              True
# │    │    └─_DenseLayer (denselayer5)         [16, 512, 7, 7]      [16, 32, 7, 7]       120,320              True
# │    │    └─_DenseLayer (denselayer6)         [16, 512, 7, 7]      [16, 32, 7, 7]       124,480              True
# │    │    └─_DenseLayer (denselayer7)         [16, 512, 7, 7]      [16, 32, 7, 7]       128,640              True
# │    │    └─_DenseLayer (denselayer8)         [16, 512, 7, 7]      [16, 32, 7, 7]       132,800              True
# │    │    └─_DenseLayer (denselayer9)         [16, 512, 7, 7]      [16, 32, 7, 7]       136,960              True
# │    │    └─_DenseLayer (denselayer10)        [16, 512, 7, 7]      [16, 32, 7, 7]       141,120              True
# │    │    └─_DenseLayer (denselayer11)        [16, 512, 7, 7]      [16, 32, 7, 7]       145,280              True
# │    │    └─_DenseLayer (denselayer12)        [16, 512, 7, 7]      [16, 32, 7, 7]       149,440              True
# │    │    └─_DenseLayer (denselayer13)        [16, 512, 7, 7]      [16, 32, 7, 7]       153,600              True
# │    │    └─_DenseLayer (denselayer14)        [16, 512, 7, 7]      [16, 32, 7, 7]       157,760              True
# │    │    └─_DenseLayer (denselayer15)        [16, 512, 7, 7]      [16, 32, 7, 7]       161,920              True
# │    │    └─_DenseLayer (denselayer16)        [16, 512, 7, 7]      [16, 32, 7, 7]       166,080              True
# │    └─BatchNorm2d (norm5)                    [16, 1024, 7, 7]     [16, 1024, 7, 7]     2,048                True
# ├─Linear (classifier)                         [16, 1024]           [16, 7]              7,175                True
# =============================================================================================================================
# Total params: 6,961,031
# Trainable params: 6,961,031
# Non-trainable params: 0
# Total mult-adds (G): 45.33
# =============================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 2888.53
# Params size (MB): 27.84
# Estimated Total Size (MB): 2926.01
# =============================================================================================================================

# %%
model = nn.DataParallel(model)  ### for two GPU faster computations

# %%
# model.load_state_dict(torch.load('/kaggle/input/efficientnetb5-trained-models/efficientnetb5_0.8016304347826086_acc - wandb - EfficientNetB5  Dataset - Aptos Gaussian Filtered EHB Tunnings - SAMPLER Batch32 Final Experimentations  Selected.pth'))

# %%
import wandb

# start a new wandb run to track this script
tracking = wandb.init(
    # set the wandb project where this run will be logged
    project="Glaucoma Fundus Imaging",
    name="HAM10000: DenseNet121",
#     name="Origa: Fb_model",
    notes="",
    # track hyperparameters and run metadata
    config={
        "learning_rate": 2e-3,
        "architecture": "fb",
        "dataset": "Default",
        "epochs": 200,
    }
)

# 4b7dfb240ea0d5aae1afac2de518c0e940547396
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20231201_065022-mlxcs0ep</code>
# Syncing run <strong><a href='https://wandb.ai/shkiam33/Glaucoma%20Fundus%20Imaging/runs/mlxcs0ep' target="_blank">HAM10000: DenseNet121</a></strong> to <a href='https://wandb.ai/shkiam33/Glaucoma%20Fundus%20Imaging' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/shkiam33/Glaucoma%20Fundus%20Imaging' target="_blank">https://wandb.ai/shkiam33/Glaucoma%20Fundus%20Imaging</a>
#  View run at <a href='https://wandb.ai/shkiam33/Glaucoma%20Fundus%20Imaging/runs/mlxcs0ep' target="_blank">https://wandb.ai/shkiam33/Glaucoma%20Fundus%20Imaging/runs/mlxcs0ep</a>

# %% [markdown]
# # **Training**

# %%
"""
Contains functions for training and testing a PyTorch model.
"""
from typing import Dict, List, Tuple
from sklearn.metrics import classification_report

import torch

from tqdm.auto import tqdm
import wandb


def train_step(model: torch.nn.Module, 
               dataloader: torch.utils.data.DataLoader, 
               loss_fn: torch.nn.Module, 
               optimizer: torch.optim.Optimizer,
               device: torch.device,
               len_train_data) -> Tuple[float, float]:
    """Trains a PyTorch model for a single epoch.

    Turns a target PyTorch model to training mode and then
    runs through all of the required training steps (forward
    pass, loss calculation, optimizer step).

    Args:
    model: A PyTorch model to be trained.
    dataloader: A DataLoader instance for the model to be trained on.
    loss_fn: A PyTorch loss function to minimize.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A tuple of training loss and training accuracy metrics.
    In the form (train_loss, train_accuracy). For example:

    (0.1112, 0.8743)
    """
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss = 0.0 
    train_acc = 0.0

    # for evaluation
    y_true_train_data = []
    y_predicted_train_data = []

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)


        # 1. Forward pass
        y_pred = model(X)
        
#         y_pred = y_pred.logits

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item() 

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        # train_acc += (y_pred_class == y).sum().item()/len(y_pred)
        train_acc += (y_pred_class == y).sum().item()
        
        # for evaluaiton
        y_true_train_data.append(y)
        y_predicted_train_data.append(y_pred_class)

    # Adjust metrics to get average loss and accuracy per batch 
    train_loss = train_loss / len(dataloader)
#     train_acc = train_acc / len(dataloader)
    train_acc = train_acc / len_train_data
    
    #     New way of accuracy calculation
    true = 0
    tot = 0
    for i in range(len(y_true_train_data)):
        x = (y_true_train_data[i] == y_predicted_train_data[i])
        for j in range(len(x)):
            tot += 1
            if x[j] == True:
                true += 1
    train_acc = (true/tot)

    # return train_loss, train_acc
    return train_loss, train_acc, y_true_train_data, y_predicted_train_data




def test_step(model: torch.nn.Module, 
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device,
              len_test_data) -> Tuple[float, float]:
    """Tests a PyTorch model for a single epoch.

    Turns a target PyTorch model to "eval" mode and then performs
    a forward pass on a testing dataset.

    Args:
    model: A PyTorch model to be tested.
    dataloader: A DataLoader instance for the model to be tested on.
    loss_fn: A PyTorch loss function to calculate loss on the test data.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A tuple of testing loss and testing accuracy metrics.
    In the form (test_loss, test_accuracy). For example:

    (0.0223, 0.8985)
    """
    # Put model in eval mode
    model.eval() 

    # Setup test loss and test accuracy values
    test_loss = 0.0 
    test_acc = 0.0

    # for evaluation
    y_true_test_data = []
    y_predicted_test_data = []


    # Turn on inference context manager
    with torch.inference_mode():

        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)
            
#             test_pred_logits = test_pred_logits.logits
            
            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            # test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))
            test_acc += (test_pred_labels == y).sum().item()

            # test_pred_labels = torch.argmax(torch.softmax(test_pred_logits, dim=1), dim=1)
            # test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels)) 
            

            # for evaluaiton
            y_true_test_data.append(y)
            y_predicted_test_data.append(test_pred_labels)


    # Adjust metrics to get average loss and accuracy per batch 
    test_loss = test_loss / len(dataloader)
#     test_acc = test_acc / len(dataloader)
    test_acc = test_acc / len_test_data


    
#     New way of accuracy calculation
    true = 0
    tot = 0
    for i in range(len(y_true_test_data)):
        x = (y_true_test_data[i] == y_predicted_test_data[i])
        for j in range(len(x)):
            tot += 1
            if x[j] == True:
                true += 1
    test_acc = (true/tot)
    
    # return test_loss, test_acc
    return test_loss, test_acc, y_true_test_data, y_predicted_test_data




def train(model: torch.nn.Module, 
          train_dataloader: torch.utils.data.DataLoader, 
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device,
          tracking,
          best_accuracy,
          len_train_data,
          len_test_data,
        ) -> Dict[str, List[float]]:
    """Trains and tests a PyTorch model.

    Passes a target PyTorch models through train_step() and test_step()
    functions for a number of epochs, training and testing the model
    in the same epoch loop.

    Calculates, prints and stores evaluation metrics throughout.

    Args:
    model: A PyTorch model to be trained and tested.
    train_dataloader: A DataLoader instance for the model to be trained on.
    test_dataloader: A DataLoader instance for the model to be tested on.
    optimizer: A PyTorch optimizer to help minimize the loss function.
    loss_fn: A PyTorch loss function to calculate loss on both datasets.
    epochs: An integer indicating how many epochs to train for.
    device: A target device to compute on (e.g. "cuda" or "cpu").

    Returns:
    A dictionary of training and testing loss as well as training and
    testing accuracy metrics. Each metric has a value in a list for 
    each epoch.
    In the form: {train_loss: [...],
              train_acc: [...],
              test_loss: [...],
              test_acc: [...]} 
    For example if training for epochs=2: 
             {train_loss: [2.0616, 1.0537],
              train_acc: [0.3945, 0.3945],
              test_loss: [1.2641, 1.5706],
              test_acc: [0.3400, 0.2973]} 
    """
    # Create empty results dictionary
    results = {"train_loss": [],
               "train_acc": [],
               "test_loss": [],
               "test_acc": []
    }


        
    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc, y_true_train_data, y_predicted_train_data = train_step(model=model,
                                                                                      dataloader=train_dataloader,
                                                                                      loss_fn=loss_fn,
                                                                                      optimizer=optimizer,
                                                                                      device=device,
                                                                                      len_train_data=len_train_data,
                                                                                      )
        test_loss, test_acc, y_true_test_data, y_predicted_test_data = test_step(model=model,
                                                                                 dataloader=test_dataloader,
                                                                                 loss_fn=loss_fn,
                                                                                 device=device,
                                                                                 len_test_data=len_test_data,
                                                                                 )

        if best_accuracy < test_acc:
            print(f"\nAccuracy Improved ({best_accuracy} to {test_acc}), Saving the model...............................................\n")
            best_accuracy = test_acc
            best_y_true_test_data = y_true_test_data
            best_y_predicted_test_data = y_predicted_test_data

            model_name_path = f"{best_accuracy} acc.pth"
            torch.save(model.state_dict(), model_name_path)
            
            
                        
            # taking "y_predicted_train_data" & "y_true_train_data" into 1D array because it came out as batch by batch 2D list
            predicted_train_data_1D = []
            true_train_data_1D = []

            for i in range(len(y_predicted_train_data)):
                for j in range(len(y_predicted_train_data[i])):
                    predicted_train_data_1D.append(y_predicted_train_data[i][j])
                    true_train_data_1D.append(y_true_train_data[i][j])

            # taking both into CPU
            predicted_train_data_cpu = torch.tensor(predicted_train_data_1D, device = 'cpu')
            true_train_data_cpu = torch.tensor(true_train_data_1D, device = 'cpu')



            # now same procedure for test data's
            predicted_test_data_1D = []
            true_test_data_1D = []

            for i in range(len(y_predicted_test_data)):
                for j in range(len(y_predicted_test_data[i])):
                    predicted_test_data_1D.append(y_predicted_test_data[i][j])
                    true_test_data_1D.append(y_true_test_data[i][j])

            # taking both into CPU
            predicted_test_data_cpu = torch.tensor(predicted_test_data_1D, device = 'cpu')
            true_test_data_cpu = torch.tensor(true_test_data_1D, device = 'cpu')



            # now same procedure for best test data's
            best_predicted_test_data_1D = []
            best_true_test_data_1D = []

            for i in range(len(best_y_predicted_test_data)):
                for j in range(len(best_y_predicted_test_data[i])):
                    best_predicted_test_data_1D.append(best_y_predicted_test_data[i][j])
                    best_true_test_data_1D.append(best_y_true_test_data[i][j])

            # taking both into CPU
            best_predicted_test_data_cpu = torch.tensor(best_predicted_test_data_1D, device = 'cpu')
            best_true_test_data_cpu = torch.tensor(best_true_test_data_1D, device = 'cpu')
            
            

            # Generate a classification report
            # F1 score on train data
            y_true_train = true_train_data_cpu
            y_pred_train = predicted_train_data_cpu

            report = classification_report(y_true_train, y_pred_train, target_names=class_names)

            print(f"Evaluation report on Train data: \n\n{report}\n\n\n\n")


            # F1 score on test data
            y_true_test = true_test_data_cpu
            y_pred_test = predicted_test_data_cpu

            report = classification_report(y_true_test, y_pred_test, target_names=class_names)

            print(f"Evaluation report on Test data: \n\n{report}")
            
            
            
            
            
            
        #     Live result tracking#####################################
        #     for i in range(len(y_true_test_data)):
        #         print(f"{y_true_test_data[i]} and {y_predicted_test_data[i]}")
        acc_0 = 0
        acc_1 = 0
        total_0 = 0
        total_1 = 0
        for i in range(len(y_predicted_test_data)):
            for j in range(len(y_true_test_data[i])):
                if (y_true_test_data[i][j] == 0):
                    total_0 += 1
                    if (y_true_test_data[i][j] == y_predicted_test_data[i][j]):
                        acc_0 += 1
                elif (y_true_test_data[i][j] == 1): 
                    total_1 += 1
                    if (y_true_test_data[i][j] == y_predicted_test_data[i][j]):
                        acc_1 += 1
#         print(f"\n0: {acc_0}/{total_0} and 1: {acc_1}/{total_1}\n\n")
        #     Live result tracking#####################################

        
        # Print out what's happening
        print(
          f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f} | "
#           f"0: {acc_0}/{total_0} | "
#           f"1: {acc_1}/{total_1}"
        )
        

        # Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

        
        tracking.log({
            "train_acc": train_acc,
            "test_acc": test_acc,
        })

    # Return the filled results at the end of the epochs
    # return results
    

    return results, y_true_train_data, y_predicted_train_data, y_true_test_data, y_predicted_test_data, best_accuracy, best_y_true_test_data, best_y_predicted_test_data
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from going_modular import engine

# Setup the optimizer to optimize our ViT model parameters using hyperparameters from the ViT paper 
optimizer = torch.optim.AdamW(params=model.parameters(), 
#                               lr=2e-3, # Base LR from Table 3 for ViT-* ImageNet-1k                                    ## learning rate decre..
                              lr = 1e-3,
                              betas=(0.9, 0.999), # default values but also mentioned in ViT paper section 4.1 (Training & Fine-tuning)
                              weight_decay=0.05,
#                               weight_decay=1e-5
                              ) # from the ViT paper section 4.1 (Training & Fine-tuning) and Table 3 for ViT-* ImageNet-1k

# lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer,T_max=5)
# Setup the loss function for multi-class classification
loss_fn = torch.nn.CrossEntropyLoss()

# Set the seeds
# set_seeds()
torch.manual_seed(42)
torch.cuda.manual_seed(42)

best_accuracy=0.0

# %%
# Train the model and save the training results to a dictionary
results, y_true_train_data, y_predicted_train_data, y_true_test_data, y_predicted_test_data, best_accuracy, best_y_true_test_data, best_y_predicted_test_data = train(model=model,
                                                                                                           train_dataloader=train_dataloader,
                                                                                                           test_dataloader=test_dataloader,
                                                                                                           optimizer=optimizer,
                                                                                                           loss_fn=loss_fn,
                                                                                                           epochs=300,
                                                                                                           device=device,
                                                                                                           tracking=tracking,
                                                                                                           best_accuracy=best_accuracy,
                                                                                                           len_train_data=len(train_data),
                                                                                                           len_test_data=len(test_data)
                                                                                                           )
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Accuracy Improved (0.0 to 0.7502502502502503), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.32      0.15      0.21       262
#          bcc       0.41      0.33      0.36       412
#          bkl       0.41      0.33      0.37       880
#           df       0.00      0.00      0.00        93
#          mel       0.42      0.27      0.33       891
#           nv       0.79      0.92      0.85      5365
#         vasc       0.46      0.19      0.27       114
#
#     accuracy                           0.71      8017
#    macro avg       0.40      0.31      0.34      8017
# weighted avg       0.66      0.71      0.68      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.46      0.25      0.32        65
#          bcc       0.58      0.45      0.51       102
#          bkl       0.58      0.31      0.40       219
#           df       0.00      0.00      0.00        22
#          mel       0.44      0.30      0.36       222
#           nv       0.81      0.96      0.88      1340
#         vasc       0.69      0.64      0.67        28
#
#     accuracy                           0.75      1998
#    macro avg       0.51      0.42      0.45      1998
# weighted avg       0.71      0.75      0.72      1998
#
# Epoch: 1 | train_loss: 0.8068 | train_acc: 0.7072 | test_loss: 0.7791 | test_acc: 0.7503 |
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Improved (0.7502502502502503 to 0.7542542542542543), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.37      0.26      0.30       262
#          bcc       0.50      0.51      0.50       412
#          bkl       0.47      0.37      0.42       880
#           df       0.40      0.02      0.04        93
#          mel       0.47      0.28      0.35       891
#           nv       0.82      0.93      0.87      5365
#         vasc       0.67      0.52      0.58       114
#
#     accuracy                           0.74      8017
#    macro avg       0.53      0.41      0.44      8017
# weighted avg       0.71      0.74      0.71      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.39      0.11      0.17        65
#          bcc       0.39      0.78      0.52       102
#          bkl       0.66      0.43      0.52       219
#           df       0.00      0.00      0.00        22
#          mel       0.53      0.18      0.26       222
#           nv       0.82      0.95      0.88      1340
#         vasc       1.00      0.57      0.73        28
#
#     accuracy                           0.75      1998
#    macro avg       0.54      0.43      0.44      1998
# weighted avg       0.73      0.75      0.72      1998
#
# Epoch: 2 | train_loss: 0.7064 | train_acc: 0.7383 | test_loss: 0.6993 | test_acc: 0.7543 |
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy Improved (0.7542542542542543 to 0.7847847847847848), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.45      0.32      0.38       262
#          bcc       0.58      0.63      0.61       412
#          bkl       0.54      0.44      0.49       880
#           df       0.44      0.04      0.08        93
#          mel       0.54      0.34      0.42       891
#           nv       0.83      0.93      0.88      5365
#         vasc       0.74      0.61      0.67       114
#
#     accuracy                           0.76      8017
#    macro avg       0.59      0.47      0.50      8017
# weighted avg       0.74      0.76      0.74      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.46      0.58      0.51        65
#          bcc       0.57      0.75      0.64       102
#          bkl       0.72      0.46      0.56       219
#           df       0.00      0.00      0.00        22
#          mel       0.53      0.43      0.48       222
#           nv       0.87      0.92      0.89      1340
#         vasc       0.62      0.75      0.68        28
#
#     accuracy                           0.78      1998
#    macro avg       0.54      0.56      0.54      1998
# weighted avg       0.77      0.78      0.77      1998
#
# Epoch: 3 | train_loss: 0.6482 | train_acc: 0.7629 | test_loss: 0.6307 | test_acc: 0.7848 |
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch: 4 | train_loss: 0.6184 | train_acc: 0.7730 | test_loss: 0.6723 | test_acc: 0.7723 |
# Epoch: 5 | train_loss: 0.5945 | train_acc: 0.7802 | test_loss: 0.7513 | test_acc: 0.7588 |
# Epoch: 6 | train_loss: 0.5808 | train_acc: 0.7887 | test_loss: 0.8300 | test_acc: 0.7412 |
#
# Accuracy Improved (0.7847847847847848 to 0.7857857857857858), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.52      0.45      0.48       262
#          bcc       0.64      0.68      0.66       412
#          bkl       0.60      0.53      0.56       880
#           df       0.53      0.26      0.35        93
#          mel       0.56      0.37      0.45       891
#           nv       0.86      0.94      0.90      5365
#         vasc       0.78      0.73      0.75       114
#
#     accuracy                           0.79      8017
#    macro avg       0.64      0.56      0.59      8017
# weighted avg       0.77      0.79      0.78      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.83      0.31      0.45        65
#          bcc       0.63      0.75      0.68       102
#          bkl       0.46      0.75      0.57       219
#           df       0.67      0.55      0.60        22
#          mel       0.63      0.30      0.40       222
#           nv       0.90      0.91      0.90      1340
#         vasc       0.90      0.64      0.75        28
#
#     accuracy                           0.79      1998
#    macro avg       0.72      0.60      0.62      1998
# weighted avg       0.80      0.79      0.78      1998
#
# Epoch: 7 | train_loss: 0.5629 | train_acc: 0.7896 | test_loss: 0.5918 | test_acc: 0.7858 |
#
# Accuracy Improved (0.7857857857857858 to 0.7972972972972973), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.51      0.45      0.48       262
#          bcc       0.68      0.73      0.70       412
#          bkl       0.61      0.54      0.58       880
#           df       0.57      0.31      0.40        93
#          mel       0.60      0.41      0.48       891
#           nv       0.87      0.94      0.90      5365
#         vasc       0.84      0.72      0.77       114
#
#     accuracy                           0.80      8017
#    macro avg       0.67      0.59      0.62      8017
# weighted avg       0.79      0.80      0.79      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.68      0.35      0.46        65
#          bcc       0.75      0.54      0.63       102
#          bkl       0.73      0.58      0.64       219
#           df       0.67      0.27      0.39        22
#          mel       0.51      0.28      0.37       222
#           nv       0.83      0.97      0.89      1340
#         vasc       0.88      0.75      0.81        28
#
#     accuracy                           0.80      1998
#    macro avg       0.72      0.53      0.60      1998
# weighted avg       0.77      0.80      0.77      1998
#
# Epoch: 8 | train_loss: 0.5385 | train_acc: 0.8009 | test_loss: 0.5526 | test_acc: 0.7973 |
#
# Accuracy Improved (0.7972972972972973 to 0.8063063063063063), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.57      0.47      0.52       262
#          bcc       0.70      0.74      0.72       412
#          bkl       0.64      0.58      0.61       880
#           df       0.50      0.32      0.39        93
#          mel       0.58      0.42      0.49       891
#           nv       0.88      0.94      0.91      5365
#         vasc       0.82      0.78      0.80       114
#
#     accuracy                           0.81      8017
#    macro avg       0.67      0.61      0.63      8017
# weighted avg       0.79      0.81      0.80      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.68      0.46      0.55        65
#          bcc       0.79      0.58      0.67       102
#          bkl       0.61      0.71      0.65       219
#           df       0.44      0.50      0.47        22
#          mel       0.73      0.27      0.40       222
#           nv       0.86      0.95      0.90      1340
#         vasc       0.80      0.71      0.75        28
#
#     accuracy                           0.81      1998
#    macro avg       0.70      0.60      0.63      1998
# weighted avg       0.80      0.81      0.79      1998
#
# Epoch: 9 | train_loss: 0.5233 | train_acc: 0.8074 | test_loss: 0.5439 | test_acc: 0.8063 |
#
# Accuracy Improved (0.8063063063063063 to 0.8088088088088088), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.57      0.48      0.52       262
#          bcc       0.68      0.75      0.71       412
#          bkl       0.65      0.58      0.61       880
#           df       0.61      0.39      0.47        93
#          mel       0.60      0.42      0.50       891
#           nv       0.88      0.94      0.91      5365
#         vasc       0.87      0.85      0.86       114
#
#     accuracy                           0.81      8017
#    macro avg       0.69      0.63      0.66      8017
# weighted avg       0.80      0.81      0.80      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.41      0.66      0.51        65
#          bcc       0.85      0.50      0.63       102
#          bkl       0.64      0.64      0.64       219
#           df       0.67      0.36      0.47        22
#          mel       0.69      0.42      0.52       222
#           nv       0.87      0.94      0.90      1340
#         vasc       0.87      0.71      0.78        28
#
#     accuracy                           0.81      1998
#    macro avg       0.72      0.61      0.64      1998
# weighted avg       0.81      0.81      0.80      1998
#
# Epoch: 10 | train_loss: 0.5007 | train_acc: 0.8125 | test_loss: 0.5414 | test_acc: 0.8088 |
# Epoch: 11 | train_loss: 0.4963 | train_acc: 0.8155 | test_loss: 0.5462 | test_acc: 0.7993 |
# Epoch: 12 | train_loss: 0.4745 | train_acc: 0.8250 | test_loss: 0.5377 | test_acc: 0.8063 |
#
# Accuracy Improved (0.8088088088088088 to 0.8123123123123123), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.58      0.48      0.52       262
#          bcc       0.72      0.75      0.73       412
#          bkl       0.65      0.61      0.63       880
#           df       0.67      0.43      0.52        93
#          mel       0.61      0.45      0.52       891
#           nv       0.89      0.94      0.91      5365
#         vasc       0.86      0.82      0.84       114
#
#     accuracy                           0.82      8017
#    macro avg       0.71      0.64      0.67      8017
# weighted avg       0.81      0.82      0.81      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.46      0.63      0.53        65
#          bcc       0.61      0.82      0.70       102
#          bkl       0.68      0.59      0.63       219
#           df       0.69      0.50      0.58        22
#          mel       0.69      0.36      0.47       222
#           nv       0.89      0.93      0.91      1340
#         vasc       0.70      0.93      0.80        28
#
#     accuracy                           0.81      1998
#    macro avg       0.67      0.68      0.66      1998
# weighted avg       0.81      0.81      0.80      1998
#
# Epoch: 13 | train_loss: 0.4814 | train_acc: 0.8199 | test_loss: 0.5295 | test_acc: 0.8123 |
# Epoch: 14 | train_loss: 0.4616 | train_acc: 0.8239 | test_loss: 0.6070 | test_acc: 0.7908 |
#
# Accuracy Improved (0.8123123123123123 to 0.8158158158158159), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.66      0.59      0.62       262
#          bcc       0.73      0.79      0.76       412
#          bkl       0.69      0.63      0.66       880
#           df       0.66      0.54      0.59        93
#          mel       0.64      0.48      0.55       891
#           nv       0.89      0.95      0.92      5365
#         vasc       0.92      0.85      0.88       114
#
#     accuracy                           0.83      8017
#    macro avg       0.74      0.69      0.71      8017
# weighted avg       0.83      0.83      0.83      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.74      0.40      0.52        65
#          bcc       0.69      0.74      0.71       102
#          bkl       0.61      0.64      0.63       219
#           df       0.92      0.50      0.65        22
#          mel       0.61      0.38      0.47       222
#           nv       0.88      0.95      0.91      1340
#         vasc       0.64      0.82      0.72        28
#
#     accuracy                           0.82      1998
#    macro avg       0.73      0.63      0.66      1998
# weighted avg       0.81      0.82      0.80      1998
#
# Epoch: 15 | train_loss: 0.4497 | train_acc: 0.8345 | test_loss: 0.5346 | test_acc: 0.8158 |
#
# Accuracy Improved (0.8158158158158159 to 0.8238238238238238), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.61      0.53      0.57       262
#          bcc       0.75      0.78      0.77       412
#          bkl       0.70      0.64      0.67       880
#           df       0.69      0.54      0.61        93
#          mel       0.64      0.49      0.55       891
#           nv       0.89      0.95      0.92      5365
#         vasc       0.91      0.87      0.89       114
#
#     accuracy                           0.83      8017
#    macro avg       0.74      0.69      0.71      8017
# weighted avg       0.82      0.83      0.83      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.48      0.69      0.57        65
#          bcc       0.75      0.73      0.74       102
#          bkl       0.71      0.68      0.69       219
#           df       0.65      0.50      0.56        22
#          mel       0.67      0.40      0.50       222
#           nv       0.89      0.94      0.91      1340
#         vasc       0.82      0.64      0.72        28
#
#     accuracy                           0.82      1998
#    macro avg       0.71      0.65      0.67      1998
# weighted avg       0.82      0.82      0.82      1998
#
# Epoch: 16 | train_loss: 0.4414 | train_acc: 0.8339 | test_loss: 0.5010 | test_acc: 0.8238 |
# Epoch: 17 | train_loss: 0.4260 | train_acc: 0.8382 | test_loss: 0.6482 | test_acc: 0.8043 |
#
# Accuracy Improved (0.8238238238238238 to 0.8293293293293293), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.61      0.59      0.60       262
#          bcc       0.76      0.77      0.76       412
#          bkl       0.71      0.66      0.68       880
#           df       0.76      0.54      0.63        93
#          mel       0.63      0.49      0.55       891
#           nv       0.90      0.95      0.92      5365
#         vasc       0.86      0.84      0.85       114
#
#     accuracy                           0.84      8017
#    macro avg       0.75      0.69      0.71      8017
# weighted avg       0.83      0.84      0.83      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.47      0.82      0.60        65
#          bcc       0.84      0.52      0.64       102
#          bkl       0.74      0.68      0.71       219
#           df       0.50      0.55      0.52        22
#          mel       0.63      0.49      0.55       222
#           nv       0.90      0.94      0.92      1340
#         vasc       0.91      0.71      0.80        28
#
#     accuracy                           0.83      1998
#    macro avg       0.71      0.67      0.68      1998
# weighted avg       0.83      0.83      0.83      1998
#
# Epoch: 18 | train_loss: 0.4314 | train_acc: 0.8363 | test_loss: 0.5098 | test_acc: 0.8293 |
# Epoch: 19 | train_loss: 0.4172 | train_acc: 0.8489 | test_loss: 0.5308 | test_acc: 0.8188 |
# Epoch: 20 | train_loss: 0.4065 | train_acc: 0.8484 | test_loss: 0.4839 | test_acc: 0.8198 |
# Epoch: 21 | train_loss: 0.3998 | train_acc: 0.8506 | test_loss: 0.5025 | test_acc: 0.8263 |
# Epoch: 22 | train_loss: 0.3882 | train_acc: 0.8538 | test_loss: 0.5283 | test_acc: 0.8068 |
# Epoch: 23 | train_loss: 0.3722 | train_acc: 0.8620 | test_loss: 0.5527 | test_acc: 0.8163 |
#
# Accuracy Improved (0.8293293293293293 to 0.8368368368368369), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.66      0.60      0.63       262
#          bcc       0.81      0.83      0.82       412
#          bkl       0.74      0.70      0.72       880
#           df       0.74      0.66      0.70        93
#          mel       0.69      0.59      0.64       891
#           nv       0.91      0.95      0.93      5365
#         vasc       0.91      0.89      0.90       114
#
#     accuracy                           0.86      8017
#    macro avg       0.78      0.74      0.76      8017
# weighted avg       0.86      0.86      0.86      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.61      0.57      0.59        65
#          bcc       0.72      0.75      0.74       102
#          bkl       0.68      0.72      0.70       219
#           df       0.50      0.64      0.56        22
#          mel       0.69      0.49      0.57       222
#           nv       0.90      0.94      0.92      1340
#         vasc       0.91      0.71      0.80        28
#
#     accuracy                           0.84      1998
#    macro avg       0.72      0.69      0.70      1998
# weighted avg       0.83      0.84      0.83      1998
#
# Epoch: 24 | train_loss: 0.3773 | train_acc: 0.8607 | test_loss: 0.4760 | test_acc: 0.8368 |
# Epoch: 25 | train_loss: 0.3574 | train_acc: 0.8640 | test_loss: 0.5652 | test_acc: 0.8228 |
# Epoch: 26 | train_loss: 0.3488 | train_acc: 0.8728 | test_loss: 0.6036 | test_acc: 0.8083 |
# Epoch: 27 | train_loss: 0.3526 | train_acc: 0.8667 | test_loss: 0.5290 | test_acc: 0.8228 |
# Epoch: 28 | train_loss: 0.3386 | train_acc: 0.8698 | test_loss: 0.5132 | test_acc: 0.8283 |
# Epoch: 29 | train_loss: 0.3326 | train_acc: 0.8726 | test_loss: 0.4812 | test_acc: 0.8338 |
# Epoch: 30 | train_loss: 0.3372 | train_acc: 0.8765 | test_loss: 0.5111 | test_acc: 0.8283 |
#
# Accuracy Improved (0.8368368368368369 to 0.8453453453453453), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.73      0.73      0.73       262
#          bcc       0.86      0.87      0.87       412
#          bkl       0.80      0.75      0.77       880
#           df       0.85      0.80      0.82        93
#          mel       0.73      0.63      0.68       891
#           nv       0.92      0.95      0.94      5365
#         vasc       0.96      0.95      0.95       114
#
#     accuracy                           0.88      8017
#    macro avg       0.84      0.81      0.82      8017
# weighted avg       0.88      0.88      0.88      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.82      0.51      0.63        65
#          bcc       0.65      0.87      0.75       102
#          bkl       0.79      0.61      0.69       219
#           df       0.65      0.68      0.67        22
#          mel       0.66      0.59      0.62       222
#           nv       0.90      0.94      0.92      1340
#         vasc       0.80      0.86      0.83        28
#
#     accuracy                           0.85      1998
#    macro avg       0.75      0.72      0.73      1998
# weighted avg       0.84      0.85      0.84      1998
#
# Epoch: 31 | train_loss: 0.3162 | train_acc: 0.8820 | test_loss: 0.4770 | test_acc: 0.8453 |
# Epoch: 32 | train_loss: 0.3051 | train_acc: 0.8855 | test_loss: 0.5649 | test_acc: 0.8268 |
# Epoch: 33 | train_loss: 0.3034 | train_acc: 0.8865 | test_loss: 0.5779 | test_acc: 0.8243 |
# Epoch: 34 | train_loss: 0.3068 | train_acc: 0.8852 | test_loss: 0.5141 | test_acc: 0.8158 |
# Epoch: 35 | train_loss: 0.2925 | train_acc: 0.8889 | test_loss: 0.5041 | test_acc: 0.8253 |
# Epoch: 36 | train_loss: 0.2799 | train_acc: 0.8910 | test_loss: 0.5165 | test_acc: 0.8418 |
# Epoch: 37 | train_loss: 0.2740 | train_acc: 0.8924 | test_loss: 0.4967 | test_acc: 0.8358 |
# Epoch: 38 | train_loss: 0.2724 | train_acc: 0.8961 | test_loss: 0.4827 | test_acc: 0.8353 |
# Epoch: 39 | train_loss: 0.2707 | train_acc: 0.8951 | test_loss: 0.5340 | test_acc: 0.8398 |
#
# Accuracy Improved (0.8453453453453453 to 0.8458458458458459), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.76      0.77      0.76       262
#          bcc       0.88      0.89      0.88       412
#          bkl       0.82      0.79      0.81       880
#           df       0.87      0.86      0.86        93
#          mel       0.78      0.68      0.73       891
#           nv       0.93      0.96      0.95      5365
#         vasc       0.92      0.88      0.90       114
#
#     accuracy                           0.90      8017
#    macro avg       0.85      0.83      0.84      8017
# weighted avg       0.89      0.90      0.90      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.62      0.66      0.64        65
#          bcc       0.72      0.77      0.75       102
#          bkl       0.77      0.66      0.71       219
#           df       0.82      0.64      0.72        22
#          mel       0.72      0.50      0.59       222
#           nv       0.89      0.95      0.92      1340
#         vasc       1.00      0.82      0.90        28
#
#     accuracy                           0.85      1998
#    macro avg       0.79      0.71      0.75      1998
# weighted avg       0.84      0.85      0.84      1998
#
# Epoch: 40 | train_loss: 0.2751 | train_acc: 0.8975 | test_loss: 0.4816 | test_acc: 0.8458 |
# Epoch: 41 | train_loss: 0.2556 | train_acc: 0.9037 | test_loss: 0.4902 | test_acc: 0.8413 |
# Epoch: 42 | train_loss: 0.2643 | train_acc: 0.9015 | test_loss: 0.5005 | test_acc: 0.8353 |
# Epoch: 43 | train_loss: 0.2312 | train_acc: 0.9133 | test_loss: 0.5552 | test_acc: 0.8288 |
# Epoch: 44 | train_loss: 0.2422 | train_acc: 0.9078 | test_loss: 0.5261 | test_acc: 0.8263 |
# Epoch: 45 | train_loss: 0.2347 | train_acc: 0.9126 | test_loss: 0.5680 | test_acc: 0.8113 |
# Epoch: 46 | train_loss: 0.2505 | train_acc: 0.9031 | test_loss: 0.5054 | test_acc: 0.8458 |
# Epoch: 47 | train_loss: 0.2296 | train_acc: 0.9163 | test_loss: 0.5298 | test_acc: 0.8288 |
#
# Accuracy Improved (0.8458458458458459 to 0.8558558558558559), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.83      0.84      0.83       262
#          bcc       0.92      0.94      0.93       412
#          bkl       0.88      0.85      0.86       880
#           df       0.91      0.83      0.87        93
#          mel       0.80      0.74      0.77       891
#           nv       0.95      0.97      0.96      5365
#         vasc       0.96      0.99      0.97       114
#
#     accuracy                           0.92      8017
#    macro avg       0.89      0.88      0.88      8017
# weighted avg       0.92      0.92      0.92      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.75      0.58      0.66        65
#          bcc       0.75      0.84      0.80       102
#          bkl       0.81      0.69      0.75       219
#           df       0.47      0.73      0.57        22
#          mel       0.69      0.57      0.62       222
#           nv       0.90      0.95      0.93      1340
#         vasc       0.92      0.79      0.85        28
#
#     accuracy                           0.86      1998
#    macro avg       0.76      0.74      0.74      1998
# weighted avg       0.85      0.86      0.85      1998
#
# Epoch: 48 | train_loss: 0.2080 | train_acc: 0.9210 | test_loss: 0.5142 | test_acc: 0.8559 |
# Epoch: 49 | train_loss: 0.2224 | train_acc: 0.9154 | test_loss: 0.5389 | test_acc: 0.8408 |
# Epoch: 50 | train_loss: 0.2121 | train_acc: 0.9215 | test_loss: 0.5290 | test_acc: 0.8338 |
# Epoch: 51 | train_loss: 0.2050 | train_acc: 0.9205 | test_loss: 0.5731 | test_acc: 0.8328 |
# Epoch: 52 | train_loss: 0.2082 | train_acc: 0.9223 | test_loss: 0.5498 | test_acc: 0.8408 |
# Epoch: 53 | train_loss: 0.2171 | train_acc: 0.9164 | test_loss: 0.5249 | test_acc: 0.8398 |
# Epoch: 54 | train_loss: 0.2002 | train_acc: 0.9229 | test_loss: 0.5395 | test_acc: 0.8403 |
# Epoch: 55 | train_loss: 0.1953 | train_acc: 0.9275 | test_loss: 0.5376 | test_acc: 0.8529 |
# Epoch: 56 | train_loss: 0.1885 | train_acc: 0.9279 | test_loss: 0.5480 | test_acc: 0.8388 |
# Epoch: 57 | train_loss: 0.1887 | train_acc: 0.9287 | test_loss: 0.5564 | test_acc: 0.8483 |
# Epoch: 58 | train_loss: 0.1830 | train_acc: 0.9315 | test_loss: 0.6333 | test_acc: 0.8348 |
# Epoch: 59 | train_loss: 0.1872 | train_acc: 0.9351 | test_loss: 0.5462 | test_acc: 0.8468 |
# Epoch: 60 | train_loss: 0.1734 | train_acc: 0.9360 | test_loss: 0.5079 | test_acc: 0.8478 |
# Epoch: 61 | train_loss: 0.1840 | train_acc: 0.9306 | test_loss: 0.5413 | test_acc: 0.8443 |
# Epoch: 62 | train_loss: 0.1822 | train_acc: 0.9316 | test_loss: 0.5756 | test_acc: 0.8453 |
# Epoch: 63 | train_loss: 0.1842 | train_acc: 0.9331 | test_loss: 0.5772 | test_acc: 0.8313 |
# Epoch: 64 | train_loss: 0.1850 | train_acc: 0.9320 | test_loss: 0.6166 | test_acc: 0.8263 |
# Epoch: 65 | train_loss: 0.1689 | train_acc: 0.9388 | test_loss: 0.5896 | test_acc: 0.8303 |
# Epoch: 66 | train_loss: 0.1565 | train_acc: 0.9421 | test_loss: 0.6049 | test_acc: 0.8398 |
# Epoch: 67 | train_loss: 0.1604 | train_acc: 0.9386 | test_loss: 0.5928 | test_acc: 0.8509 |
# Epoch: 68 | train_loss: 0.1590 | train_acc: 0.9404 | test_loss: 0.5577 | test_acc: 0.8488 |
# Epoch: 69 | train_loss: 0.1766 | train_acc: 0.9361 | test_loss: 0.5881 | test_acc: 0.8423 |
# Epoch: 70 | train_loss: 0.1680 | train_acc: 0.9364 | test_loss: 0.6037 | test_acc: 0.8278 |
# Epoch: 71 | train_loss: 0.1509 | train_acc: 0.9440 | test_loss: 0.5304 | test_acc: 0.8539 |
# Epoch: 72 | train_loss: 0.1704 | train_acc: 0.9371 | test_loss: 0.5533 | test_acc: 0.8348 |
# Epoch: 73 | train_loss: 0.1556 | train_acc: 0.9420 | test_loss: 0.5985 | test_acc: 0.8343 |
# Epoch: 74 | train_loss: 0.1574 | train_acc: 0.9394 | test_loss: 0.5883 | test_acc: 0.8403 |
# Epoch: 75 | train_loss: 0.1574 | train_acc: 0.9424 | test_loss: 0.5883 | test_acc: 0.8393 |
# Epoch: 76 | train_loss: 0.1539 | train_acc: 0.9446 | test_loss: 0.5466 | test_acc: 0.8483 |
# Epoch: 77 | train_loss: 0.1395 | train_acc: 0.9467 | test_loss: 0.5712 | test_acc: 0.8408 |
# Epoch: 78 | train_loss: 0.1634 | train_acc: 0.9389 | test_loss: 0.6137 | test_acc: 0.8318 |
# Epoch: 79 | train_loss: 0.1480 | train_acc: 0.9471 | test_loss: 0.6139 | test_acc: 0.8373 |
# Epoch: 80 | train_loss: 0.1407 | train_acc: 0.9484 | test_loss: 0.6062 | test_acc: 0.8493 |
# Epoch: 81 | train_loss: 0.1544 | train_acc: 0.9422 | test_loss: 0.5629 | test_acc: 0.8448 |
# Epoch: 82 | train_loss: 0.1542 | train_acc: 0.9449 | test_loss: 0.6086 | test_acc: 0.8313 |
# Epoch: 83 | train_loss: 0.1469 | train_acc: 0.9456 | test_loss: 0.5709 | test_acc: 0.8448 |
# Epoch: 84 | train_loss: 0.1270 | train_acc: 0.9547 | test_loss: 0.7106 | test_acc: 0.8333 |
# Epoch: 85 | train_loss: 0.1436 | train_acc: 0.9482 | test_loss: 0.6005 | test_acc: 0.8448 |
# Epoch: 86 | train_loss: 0.1451 | train_acc: 0.9454 | test_loss: 0.6213 | test_acc: 0.8443 |
# Epoch: 87 | train_loss: 0.1368 | train_acc: 0.9501 | test_loss: 0.6169 | test_acc: 0.8193 |
# Epoch: 88 | train_loss: 0.1339 | train_acc: 0.9516 | test_loss: 0.6730 | test_acc: 0.8343 |
# Epoch: 89 | train_loss: 0.1379 | train_acc: 0.9553 | test_loss: 0.6476 | test_acc: 0.8448 |
# Epoch: 90 | train_loss: 0.1298 | train_acc: 0.9521 | test_loss: 0.6661 | test_acc: 0.8108 |
# Epoch: 91 | train_loss: 0.1378 | train_acc: 0.9490 | test_loss: 0.6876 | test_acc: 0.8358 |
# Epoch: 92 | train_loss: 0.1432 | train_acc: 0.9462 | test_loss: 0.6852 | test_acc: 0.8268 |
# Epoch: 93 | train_loss: 0.1290 | train_acc: 0.9537 | test_loss: 0.5825 | test_acc: 0.8413 |
#
# Accuracy Improved (0.8558558558558559 to 0.8563563563563563), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.90      0.90      0.90       262
#          bcc       0.95      0.95      0.95       412
#          bkl       0.90      0.91      0.90       880
#           df       0.93      0.90      0.92        93
#          mel       0.87      0.85      0.86       891
#           nv       0.97      0.97      0.97      5365
#         vasc       0.97      0.96      0.96       114
#
#     accuracy                           0.95      8017
#    macro avg       0.93      0.92      0.92      8017
# weighted avg       0.95      0.95      0.95      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.76      0.69      0.73        65
#          bcc       0.80      0.78      0.79       102
#          bkl       0.73      0.69      0.71       219
#           df       0.75      0.68      0.71        22
#          mel       0.78      0.48      0.60       222
#           nv       0.89      0.96      0.92      1340
#         vasc       0.95      0.71      0.82        28
#
#     accuracy                           0.86      1998
#    macro avg       0.81      0.72      0.75      1998
# weighted avg       0.85      0.86      0.85      1998
#
# Epoch: 94 | train_loss: 0.1419 | train_acc: 0.9477 | test_loss: 0.5794 | test_acc: 0.8564 |
#
# Accuracy Improved (0.8563563563563563 to 0.8578578578578578), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.91      0.91      0.91       262
#          bcc       0.95      0.97      0.96       412
#          bkl       0.92      0.90      0.91       880
#           df       0.96      0.97      0.96        93
#          mel       0.89      0.87      0.88       891
#           nv       0.97      0.98      0.98      5365
#         vasc       0.99      1.00      1.00       114
#
#     accuracy                           0.95      8017
#    macro avg       0.94      0.94      0.94      8017
# weighted avg       0.95      0.95      0.95      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.66      0.65      0.65        65
#          bcc       0.66      0.86      0.75       102
#          bkl       0.76      0.73      0.74       219
#           df       0.92      0.55      0.69        22
#          mel       0.68      0.62      0.65       222
#           nv       0.93      0.93      0.93      1340
#         vasc       0.96      0.86      0.91        28
#
#     accuracy                           0.86      1998
#    macro avg       0.80      0.74      0.76      1998
# weighted avg       0.86      0.86      0.86      1998
#
# Epoch: 95 | train_loss: 0.1270 | train_acc: 0.9543 | test_loss: 0.5305 | test_acc: 0.8579 |
# Epoch: 96 | train_loss: 0.1211 | train_acc: 0.9552 | test_loss: 0.6994 | test_acc: 0.8163 |
#
# Accuracy Improved (0.8578578578578578 to 0.8633633633633634), Saving the model...............................................
#
# Evaluation report on Train data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.93      0.92      0.93       262
#          bcc       0.96      0.94      0.95       412
#          bkl       0.91      0.92      0.91       880
#           df       0.96      0.95      0.95        93
#          mel       0.89      0.86      0.87       891
#           nv       0.97      0.98      0.97      5365
#         vasc       0.98      0.96      0.97       114
#
#     accuracy                           0.95      8017
#    macro avg       0.94      0.93      0.94      8017
# weighted avg       0.95      0.95      0.95      8017
#
#
#
#
#
# Evaluation report on Test data:
#
#               precision    recall  f1-score   support
#
#        akiec       0.81      0.52      0.64        65
#          bcc       0.85      0.75      0.80       102
#          bkl       0.78      0.68      0.73       219
#           df       0.75      0.68      0.71        22
#          mel       0.66      0.70      0.68       222
#           nv       0.91      0.95      0.93      1340
#         vasc       1.00      0.86      0.92        28
#
#     accuracy                           0.86      1998
#    macro avg       0.82      0.73      0.77      1998
# weighted avg       0.86      0.86      0.86      1998
#
# Epoch: 97 | train_loss: 0.1257 | train_acc: 0.9532 | test_loss: 0.5657 | test_acc: 0.8634 |
# Epoch: 98 | train_loss: 0.1416 | train_acc: 0.9496 | test_loss: 0.5886 | test_acc: 0.8519 |
# Epoch: 99 | train_loss: 0.1167 | train_acc: 0.9580 | test_loss: 0.6404 | test_acc: 0.8183 |
# Epoch: 100 | train_loss: 0.1449 | train_acc: 0.9479 | test_loss: 0.5759 | test_acc: 0.8438 |
# Epoch: 101 | train_loss: 0.1284 | train_acc: 0.9552 | test_loss: 0.6862 | test_acc: 0.8408 |
# Epoch: 102 | train_loss: 0.1278 | train_acc: 0.9543 | test_loss: 0.7140 | test_acc: 0.7978 |
# Epoch: 103 | train_loss: 0.1183 | train_acc: 0.9603 | test_loss: 0.6064 | test_acc: 0.8383 |
# Epoch: 104 | train_loss: 0.1225 | train_acc: 0.9537 | test_loss: 0.6038 | test_acc: 0.8478 |
# Epoch: 105 | train_loss: 0.1081 | train_acc: 0.9621 | test_loss: 0.5297 | test_acc: 0.8549 |
# Epoch: 106 | train_loss: 0.1351 | train_acc: 0.9505 | test_loss: 0.5576 | test_acc: 0.8483 |
# Epoch: 107 | train_loss: 0.1307 | train_acc: 0.9546 | test_loss: 0.5911 | test_acc: 0.8393 |
# Epoch: 108 | train_loss: 0.1192 | train_acc: 0.9592 | test_loss: 0.5737 | test_acc: 0.8478 |
# Epoch: 109 | train_loss: 0.1420 | train_acc: 0.9496 | test_loss: 0.6012 | test_acc: 0.8534 |
# Epoch: 110 | train_loss: 0.1256 | train_acc: 0.9575 | test_loss: 0.6340 | test_acc: 0.8443 |
# Epoch: 111 | train_loss: 0.1118 | train_acc: 0.9606 | test_loss: 0.5689 | test_acc: 0.8564 |
# Epoch: 112 | train_loss: 0.1201 | train_acc: 0.9566 | test_loss: 0.6255 | test_acc: 0.8509 |
# Epoch: 113 | train_loss: 0.1013 | train_acc: 0.9635 | test_loss: 0.6461 | test_acc: 0.8448 |
# Epoch: 114 | train_loss: 0.1276 | train_acc: 0.9547 | test_loss: 0.6041 | test_acc: 0.8589 |
